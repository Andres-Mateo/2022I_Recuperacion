# %% [markdown]
# <img src="data:image/png;base64,..." width=300 height=240 />
#
# # EXAMEN RECUPERACION BIOINFORMTICA
#
# ## GBI6-2021II: BIOINFORMÁTICA
#
# **Benalcazar Mera, Andres Mateo**
#
# **17-08-2022**

# %% [markdown]
# **Vaya a alguno de los siguientes enlaces:**
#
# ▪ https://www.genenames.org/data/genegroup/#!/group/1054,
#
# ▪ http://ribosome.med.miyazaki-u.ac.jp/rpg.cgi?mode=orglist&org=Homo%20sapiens&type=m,
#
# ▪ https://www.arb-silva.de/browser/ssu-138.1/AADB02002318
#
# **En ellas se tiene información sobre las proteínas o RNA ribosomales:**
#
# • S Ribosomal proteins:
#
# • L Ribosomal proteins:
#
# • S Ribosomal proteins – Mitochondrial: Mateo Benalcazar
#
# • L Ribosomal proteins – Mitochondrial:
#
# • RNA ribosomal

# %% [markdown]
# ## INTRODUCCION
#    El ribosoma es una organelo celular muy importante que se desembuelve sobretodo en el dogma central de la biologia, pues, al ser el encargado de traducir en mRNA en proteinas este permite que se desarrolle la vida como la conocemos [1]. Los ribosomas estan contituidos por dos subunidades de ARN y proteinas, estas subunidades revelan la arquitectura compleja que se deriva de la red de interacciones que conectan las proteínas r individuales entre sí y con el ARNr [4].
#
#
# <img src="https://www.ncbi.nlm.nih.gov/corecgi/tileshop/tileshop.fcgi?p=PMC3&id=277960&s=30&r=2&c=1" width=350 height=240 />
#
#
#
#    La subunidad ribosómica pequeña se une a los ARN mensajeros (ARNm) y traduce el mensaje codificado seleccionando moléculas de ARN de transferencia de aminoacil (ARNt) afines, por otro lado, la subunidad grande contiene el sitio catalítico ribosómico denominado centro de peptidil transferasa (PTC), que cataliza la formación de enlaces peptídicos, polimerizando así los aminoácidos entregados por los tRNA en una cadena polipeptídica [4].
#
#
# <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3331703/bin/cshperspect-TRA-011536_F5.jpg" width=350 height=260/>
#
#
#
#    Las mitocondrias son uno de los orgnalenos mas importante de la celula, pues, al estar encargados de convertir energia en forma de ATP, tambien estan relacionados en procesos como la apoptósis y enveceimiento celular [4]. Los ribosomas que sintetizan oproteinas en las mitocondrias son llamados mitoribozomas[2,3], estos son macroestructuras de origen genético dual, formadas por 3 componentes de ARN mitoribosómico codificados en el ADNmt y 89 componentes proteicos específicos codificados en el ADN nuclear [2]. Sin embargo, aunque los mitoribosomas se derivan evolutivamente de los ribosomas bacterianos, se han diferenciado mucho de ellos en términos de composición, función y estructura [4].
#
#
#
# <img src="https://image.slidesharecdn.com/mitocondrias-101028144919-phpapp01/85/mitocondrias-12-320.jpg?cb=1659112630" witdh=350 height=280/>
#
#
#    Recientemente se ha hablado mucho acerca de la relacion entre los mitoribozomas y el cancer, pues, como se sabe las mitocondrias participan en la apoptósis, ademas, en recientes estudios se ha encontrado alteraciones en los niveles de proteínas del mitoribosoma o factores de ensamblaje asociados con el desarrollo de cánceres [2]. Lo cual tiene sentido puesto que los mitoribozomas tienen mucho que ver dentro de la respiracion celular, de modo que si la célula llega a tener aulguna mutacion (cancer) son las encargadas de generar apoptósis y evitar la propagacion de la mutacion [3].
#
#
#
# <img src="https://www.greberlab.org/uploads/1/3/3/5/133583913/montage_orig.jpg" width=300 height=240 />
#
#
#
# ### Biopython
#    Es una asociación internacional de desarrolladores de herramientas Python disponibles gratuitamente para biología molecular computacional. Python es un lenguaje flexible, interpretado y orientado a objetos que se está volviendo cada vez más popular para la computación científica [7]. Biopython tambien es un esfuerzo colaborativo distribuido para desarrollar bibliotecas y aplicaciones de Python que aborden las necesidades del trabajo actual y futuro en bioinformática. El código fuente está disponible bajo la Licencia Biopython , que es extremadamente liberal y compatible con casi todas las licencias del mundo[6].
#
#
# <img src="data:image/png;base64,..." width=300 height=240 />

# %% [markdown]
# ## Ejercicio 1 [1 punto]
# ### Crear un repositorio de nombre “2022I_Recuperacion”. Generar un Readme con los detalles de las actividades, del equipo utilizado y de los programas utilizados. Mantenga un control de cambios.

# %% [markdown]
# Enlace del repositorio: https://github.com/Andres-Mateo/2022I_Recuperacion

# %% [markdown]
# ## Ejercicio 2 [1 punto]
# #### Con el grupo de componentes ribosomales seleccionado, realizar una búsqueda con Python de la información para cada componente (formato gdb) y separar en secuencias para células humanas sanas y cancerosas.

# %%
from Bio import Entrez
from Bio import SeqIO
import re
import os

# %%
records = [] 
seq_cell_sana = []
comments = []
comentarios=[]
id_enfermas = []
id_sanas = []
out_sequence = []
cell_enfermas = []
cell_sanas = []
len_sequences=[]

# %%
ID=[ "NM_018141.4", "AB051349.1", "Y11681.1", "AB049946.1", "AB051350.1", "AB051351", "AB051352.1",
    "AB049952.1", "AF100761", "NM_001297767", "AB051353", "AF226045", "AB061206", "AB061207", "AB061208", "AB051354"]

# %%
Entrez.email = "andres.benalcazar@est.ikiam.edu.ec" 
with Entrez.efetch( db="nucleotide", rettype="gb", retmode="text", id= ID) as handle:
  
    for seq_record in SeqIO.parse(handle, "gb"):
        seq = seq_record.seq
        record = seq_record.annotations
        records.append(record)
        
        if "cancer" in records:
            cell_enfermas.append(len(seq_record))
            len_sequences.append(repr(seq))
            id_enfermas.append(seq)
            comments.append(record["comment"])
            print("celula infectada con cancer")
        else: 
            cell_sanas.append(len(seq_record))
            seq_cell_sana.append(repr(seq_record.seq))
            id_sanas.append(seq_record.id)
            print("sana")
        
Total_seq = seq_cell_sana + len_sequences
Total_id = id_enfermas + id_sanas
# Out:
# sana
# sana
# sana
# sana
# sana
# sana
# sana
# sana
# sana
# sana
# sana
# sana
# sana
# sana
# sana
# sana

# %%
records
# Out:
# [{'molecule_type': 'mRNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '02-JUN-2022',
#   'accessions': ['NM_018141'],
#   'sequence_version': 4,
#   'keywords': ['RefSeq', 'MANE Select'],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='Structure and Function of the Mitochondrial Ribosome', ...),
#    Reference(title='Ribosome. The structure of the human mitochondrial ribosome', ...),
#    Reference(title='Image-based genome-wide siRNA screen identifies selective autophagy factors', ...),
#    Reference(title='Genetic variants in nuclear-encoded mitochondrial genes influence AIDS progression', ...),
#    Reference(title='The DNA sequence and analysis of human chromosome 6', ...),
#    Reference(title='Identification and characterization of over 100 mitochondrial ribosomal protein pseudogenes in the human genome', ...),
#    Reference(title='Gene expression profile of human bone marrow stromal cells: high-throughput expressed sequence tag sequencing analysis', ...),
#    Reference(title='The small subunit of the mammalian mitochondrial ribosome. Identification of the full complement of ribosomal proteins present', ...),
#    Reference(title='A proteomics approach to the identification of mammalian mitochondrial small subunit ribosomal proteins', ...)],
#   'comment': 'REVIEWED REFSEQ: This record has been curated by NCBI staff. The\nreference sequence was derived from BG776014.1, BC012560.1,\nAW974308.1, AI754661.1, AI683142.1, AW300686.1 and AF113220.1.\nOn Nov 22, 2018 this sequence version replaced NM_018141.3.\nSummary: Mammalian mitochondrial ribosomal proteins are encoded by\nnuclear genes and help in protein synthesis within the\nmitochondrion. Mitochondrial ribosomes (mitoribosomes) consist of a\nsmall 28S subunit and a large 39S subunit. They have an estimated\n75% protein to rRNA composition compared to prokaryotic ribosomes,\nwhere this ratio is reversed. Another difference between mammalian\nmitoribosomes and prokaryotic ribosomes is that the latter contain\na 5S rRNA. Among different species, the proteins comprising the\nmitoribosome differ greatly in sequence, and sometimes in\nbiochemical properties, which prevents easy recognition by sequence\nhomology. This gene encodes a 28S subunit protein that belongs to\nthe ribosomal protein S10P family. Pseudogenes corresponding to\nthis gene are found on chromosomes 1q, 3p, and 9p. [provided by\nRefSeq, Jul 2008].\nCOMPLETENESS: full length.',
#   'structured_comment': OrderedDict([('Evidence-Data',
#                 OrderedDict([('Transcript exon combination',
#                               'BC012560.1, AK098446.1 [ECO:0000332]'),
#                              ('RNAseq introns',
#                               'mixed sample support SAMEA1965299, SAMEA1966682 [ECO:0006172]')])),
#                ('RefSeq-Attributes',
#                 OrderedDict([('gene product(s) localized to mito.',
#                               'reported by MitoCarta'),
#                              ('MANE Ensembl match',
#                               'ENST00000053468.4/ ENSP00000053468.3'),
#                              ('RefSeq Select criteria',
#                               'based on conservation, expression')]))])},
#  {'molecule_type': 'DNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '21-JUL-2016',
#   'accessions': ['AB051349'],
#   'sequence_version': 1,
#   'keywords': [''],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='The human mitochondrial ribosomal protein genes: mapping of 54 genes to the chromosomes and implications for human disorders', ...),
#    Reference(title='Direct Submission', ...)]},
#  {'molecule_type': 'mRNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '07-OCT-2008',
#   'accessions': ['Y11681'],
#   'sequence_version': 1,
#   'keywords': ['mitochondrial ribosomal protein S12'],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='Metazoan sequences for mitoribosomal protein S12', ...),
#    Reference(title='Direct Submission', ...)]},
#  {'molecule_type': 'mRNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '31-AUG-2001',
#   'accessions': ['AB049946'],
#   'sequence_version': 1,
#   'keywords': [''],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='Proteomic analysis of the mammalian mitochondrial ribosome. Identification of protein components in the 28 S small subunit', ...),
#    Reference(title='Direct Submission', ...)]},
#  {'molecule_type': 'DNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '21-JUL-2016',
#   'accessions': ['AB051350'],
#   'sequence_version': 1,
#   'keywords': [''],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='The human mitochondrial ribosomal protein genes: mapping of 54 genes to the chromosomes and implications for human disorders', ...),
#    Reference(title='Direct Submission', ...)]},
#  {'molecule_type': 'DNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '21-JUL-2016',
#   'accessions': ['AB051351'],
#   'sequence_version': 1,
#   'keywords': [''],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='The human mitochondrial ribosomal protein genes: mapping of 54 genes to the chromosomes and implications for human disorders', ...),
#    Reference(title='Direct Submission', ...)]},
#  {'molecule_type': 'DNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '21-JUL-2016',
#   'accessions': ['AB051352'],
#   'sequence_version': 1,
#   'keywords': [''],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='The human mitochondrial ribosomal protein genes: mapping of 54 genes to the chromosomes and implications for human disorders', ...),
#    Reference(title='Direct Submission', ...)]},
#  {'molecule_type': 'mRNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '31-AUG-2001',
#   'accessions': ['AB049952'],
#   'sequence_version': 1,
#   'keywords': [''],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='Proteomic analysis of the mammalian mitochondrial ribosome. Identification of protein components in the 28 S small subunit', ...),
#    Reference(title='Direct Submission', ...)]},
#  {'molecule_type': 'mRNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '08-JUL-1999',
#   'accessions': ['AF100761'],
#   'sequence_version': 1,
#   'keywords': ['FLI_CDNA'],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='Human PTD017 gene', ...),
#    Reference(title='Direct Submission', ...)]},
#  {'molecule_type': 'mRNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '09-JUN-2022',
#   'accessions': ['NM_001297767', 'XM_005263043'],
#   'sequence_version': 2,
#   'keywords': ['RefSeq'],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='Expression pattern of MRPS18 family genes in gliomas', ...),
#    Reference(title='An innovative strategy to clone positive modifier genes of defects caused by mtDNA mutations: MRPS18C as suppressor gene of m.3946G>A mutation in MT-ND1 gene', ...),
#    Reference(title='Structure and Function of the Mitochondrial Ribosome', ...),
#    Reference(title='Ribosome. The structure of the human mitochondrial ribosome', ...),
#    Reference(title='Genetic variants in nuclear-encoded mitochondrial genes influence AIDS progression', ...),
#    Reference(title='Identification and characterization of over 100 mitochondrial ribosomal protein pseudogenes in the human genome', ...),
#    Reference(title='The small subunit of the mammalian mitochondrial ribosome. Identification of the full complement of ribosomal proteins present', ...)],
#   'comment': "REVIEWED REFSEQ: This record has been curated by NCBI staff. The\nreference sequence was derived from CN262115.1 and AC096768.3.\nOn Aug 14, 2020 this sequence version replaced NM_001297767.1.\nSummary: Mammalian mitochondrial ribosomal proteins are encoded by\nnuclear genes and help in protein synthesis within the\nmitochondrion. Mitochondrial ribosomes (mitoribosomes) consist of a\nsmall 28S subunit and a large 39S subunit. They have an estimated\n75% protein to rRNA composition compared to prokaryotic ribosomes,\nwhere this ratio is reversed. Another difference between mammalian\nmitoribosomes and prokaryotic ribosomes is that the latter contain\na 5S rRNA. Among different species, the proteins comprising the\nmitoribosome differ greatly in sequence, and sometimes in\nbiochemical properties, which prevents easy recognition by sequence\nhomology. This gene encodes a 28S subunit protein that belongs to\nthe ribosomal protein S18P family. The encoded protein is one of\nthree that has significant sequence similarity to bacterial S18\nproteins. The primary sequences of the three human mitochondrial\nS18 proteins are no more closely related to each other than they\nare to the prokaryotic S18 proteins. Pseudogenes corresponding to\nthis gene are found on chromosomes 8p, 12p, 15q, and 22q. [provided\nby RefSeq, Jul 2008].\nTranscript Variant: This variant (2) lacks an in-frame exon in the\ncentral coding region, compared to variant 1. The encoded isoform\n(2) is shorter, compared to isoform 1.\nSequence Note: This RefSeq record was created from transcript and\ngenomic sequence data to make the sequence consistent with the\nreference genome assembly. The genomic coordinates used for the\ntranscript record were based on transcript alignments.\nCOMPLETENESS: complete on the 3' end.",
#   'structured_comment': OrderedDict([('Evidence-Data',
#                 OrderedDict([('Transcript exon combination',
#                               'SRR1803611.166264.1, SRR1660809.214864.1 [ECO:0000332]'),
#                              ('RNAseq introns',
#                               'single sample supports all introns SAMEA1965299, SAMEA1966682 [ECO:0000348]')])),
#                ('RefSeq-Attributes',
#                 OrderedDict([('gene product(s) localized to mito.',
#                               'reported by MitoCarta')]))])},
#  {'molecule_type': 'DNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '08-FEB-2002',
#   'accessions': ['AB051353'],
#   'sequence_version': 1,
#   'keywords': [''],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='The human mitochondrial ribosomal protein genes: mapping of 54 genes to the chromosomes and implications for human disorders', ...),
#    Reference(title='Direct Submission', ...)]},
#  {'molecule_type': 'mRNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '20-JUL-2000',
#   'accessions': ['AF226045'],
#   'sequence_version': 1,
#   'keywords': ['FLI_CDNA'],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='A novel gene expressed in human liver cancer tissue', ...),
#    Reference(title='Direct Submission', ...)]},
#  {'molecule_type': 'DNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '21-JUL-2016',
#   'accessions': ['AB061206'],
#   'sequence_version': 1,
#   'keywords': [''],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='The human mitochondrial ribosomal protein genes: mapping of 54 genes to the chromosomes and implications for human disorders', ...),
#    Reference(title='Direct Submission', ...)]},
#  {'molecule_type': 'DNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '21-JUL-2016',
#   'accessions': ['AB061207'],
#   'sequence_version': 1,
#   'keywords': [''],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='The human mitochondrial ribosomal protein genes: mapping of 54 genes to the chromosomes and implications for human disorders', ...),
#    Reference(title='Direct Submission', ...)]},
#  {'molecule_type': 'DNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '21-JUL-2016',
#   'accessions': ['AB061208'],
#   'sequence_version': 1,
#   'keywords': [''],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='The human mitochondrial ribosomal protein genes: mapping of 54 genes to the chromosomes and implications for human disorders', ...),
#    Reference(title='Direct Submission', ...)]},
#  {'molecule_type': 'DNA',
#   'topology': 'linear',
#   'data_file_division': 'PRI',
#   'date': '21-JUL-2016',
#   'accessions': ['AB051354'],
#   'sequence_version': 1,
#   'keywords': [''],
#   'source': 'Homo sapiens (human)',
#   'organism': 'Homo sapiens',
#   'taxonomy': ['Eukaryota',
#    'Metazoa',
#    'Chordata',
#    'Craniata',
#    'Vertebrata',
#    'Euteleostomi',
#    'Mammalia',
#    'Eutheria',
#    'Euarchontoglires',
#    'Primates',
#    'Haplorrhini',
#    'Catarrhini',
#    'Hominidae',
#    'Homo'],
#   'references': [Reference(title='The human mitochondrial ribosomal protein genes: mapping of 54 genes to the chromosomes and implications for human disorders', ...),
#    Reference(title='Direct Submission', ...)]}]

# %%
from Bio import Entrez

out_sequence = open("MPRS_secuencias.fasta", "w")

for linea in Total_seq :  
    Entrez.email="andres.benalcazar@est.ikiam.edu.ec"
    handle=Entrez.efetch(db="nucleotide" , id= ID, rettype="fasta", retmode="text")
    data=(handle.read())
    out_sequence.write(data)
out_sequence.close()

# %%
print ("De lo consultado, existen", len(records), "secuencias que van hacer analizadas")

print ("de las cuales", len(len_sequences), "son secuencias de celulas dañadas o con cancer") 

print ("y", len(seq_cell_sana), "son secuencias de células sanas")
# Out:
# De lo consultado, existen 16 secuencias que van hacer analizadas
# de las cuales 0 son secuencias de celulas dañadas o con cancer
# y 16 son secuencias de células sanas

# %%
len(Total_seq)
# Out:
# 116

# %% [markdown]
# ## Ejercicio 3 [1 punto]
# ### Realizar un histograma (matplotlib) para cada componente con el número de nucleótidos de las secuencias. Explique los hallazgos.

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
Histograma =[] 
Entrez.email = "andres.benalcazar@est.ikiam.edu.ec"
ofile=open("MPRS_secuencias.fasta", "w")
with Entrez.efetch(db="nucleotide" ,id=ID ,rettype="fasta", retmode="text") as hdl:
    for seq_record in SeqIO.parse(hdl, "fasta"):
        ofile.write(">"+str(seq_record)+str(seq_record.description[:50])+"n")
        ofile.write(str(seq_record)+"\n")
        ofile.write("\n")
        Histograma.append(len(seq_record))

# %%
Histograma
# Out:
# [2100,
#  253,
#  1094,
#  837,
#  333,
#  322,
#  158,
#  837,
#  1414,
#  1466,
#  154,
#  1155,
#  189,
#  237,
#  246,
#  203]

# %%
plt.title('Comparacion de Sanas vs cancer')
plt.xlabel('total hallazgos', fontsize = 14, rotation = 0)
plt.ylabel('Frecuencia', fontsize = 14, rotation = 90) 
plt.hist(Histograma, bins = 5, color = "#F2AB6D", rwidth=0.3)
plt.show()

# %% [markdown]
# como se puede observar en el histograma, la cantidad de celulas con cancer es 0, lo que quiere decir que todas las celulas estan sanas, ademas, se puede obvervar un valor sobresaliendo, este valor indica que de todas las secuencias analizadas hay una que se repite, la cual haciendo su respectiva busqueda son las MPRS15A y MPRS108B.

# %% [markdown]
# ## Pregunta 4 [2 puntos]
# ### Realizar un árbol filogenético donde se muestre las secuencias de células normales y las células cancerosas. Explique los hallazgos.

# %%
from Bio import SeqIO
from Bio import AlignIO
from Bio import Phylo
from Bio.Align.Applications import ClustalwCommandline
import os

# %%
clustalw_exe = r"C:\Program Files (x86)\ClustalW2\clustalw2.exe"
clustalw_cline = ClustalwCommandline(clustalw_exe, infile = "MPRS_secuencias.fasta")
assert os.path.isfile(clustalw_exe), "Clustal_W executable is missing or not found"
stdout, stderr = clustalw_cline()
print(clustalw_cline)
ClustalAlign = AlignIO.read("secuencias.aln", "clustal")
print(ClustalAlign)
tree = Phylo.read("MPRS_secuencias.dnd", "newick")
# Out:
# ---------------------------------------------------------------------------
# ApplicationError                          Traceback (most recent call last)
# Input In [140], in <cell line: 4>()
#       2 clustalw_cline = ClustalwCommandline(clustalw_exe, infile = "MPRS_secuencias.fasta")
#       3 assert os.path.isfile(clustalw_exe), "Clustal_W executable is missing or not found"
# ----> 4 stdout, stderr = clustalw_cline()
#       5 print(clustalw_cline)
#       6 ClustalAlign = AlignIO.read("secuencias.aln", "clustal")
#
# File ~\anaconda3\lib\site-packages\Bio\Application\__init__.py:574, in AbstractCommandline.__call__(self, stdin, stdout, stderr, cwd, env)
#     571     stderr_arg.close()
#     573 if return_code:
# --> 574     raise ApplicationError(return_code, str(self), stdout_str, stderr_str)
#     575 return stdout_str, stderr_str
#
# ApplicationError: Non-zero return code 4294967295 from '"C:\\Program Files (x86)\\ClustalW2\\clustalw2.exe" -infile=MPRS_secuencias.fasta', message 'ERROR: Multiple sequences found with same name (found ID_ at least twice)!'

# %%
from Bio import Phylo
tree = Phylo.read("MPRS_secuencias.dnd", "newick")
Phylo.draw_ascii(tree)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [141], in <cell line: 2>()
#       1 from Bio import Phylo
# ----> 2 tree = Phylo.read("MPRS_secuencias.dnd", "newick")
#       3 Phylo.draw_ascii(tree)
#
# File ~\anaconda3\lib\site-packages\Bio\Phylo\_io.py:60, in read(file, format, **kwargs)
#      58 try:
#      59     tree_gen = parse(file, format, **kwargs)
# ---> 60     tree = next(tree_gen)
#      61 except StopIteration:
#      62     raise ValueError("There are no trees in this file.") from None
#
# File ~\anaconda3\lib\site-packages\Bio\Phylo\_io.py:48, in parse(file, format, **kwargs)
#      33 def parse(file, format, **kwargs):
#      34     """Parse a file iteratively, and yield each of the trees it contains.
#      35
#      36     If a file only contains one tree, this still returns an iterable object that
#    (...)
#      46
#      47     """
# ---> 48     with File.as_handle(file) as fp:
#      49         yield from getattr(supported_formats[format], "parse")(fp, **kwargs)
#
# File ~\anaconda3\lib\contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File ~\anaconda3\lib\site-packages\Bio\File.py:72, in as_handle(handleish, mode, **kwargs)
#      30 r"""Context manager to ensure we are using a handle.
#      31
#      32 Context manager for arguments that can be passed to SeqIO and AlignIO read, write,
#    (...)
#      69
#      70 """
#      71 try:
# ---> 72     with open(handleish, mode, **kwargs) as fp:
#      73         yield fp
#      74 except TypeError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'MPRS_secuencias.dnd'

# %%
with open("MPRS_secuencia.aln","r") as aln: 
    alignment = AlignIO.read(aln,"clustal")
print(type(alignment))

# %%
from Bio.Phylo.TreeConstruction import DistanceCalculator 
calculator = DistanceCalculator('identity')

# %%
distance_matrix = calculator.get_distance(alignment)
print(distance_matrix)

# %%
from Bio.Phylo.TreeConstruction import DistanceTreeConstructor
constructor = DistanceTreeConstructor(calculator)

# %%
rag2_tree = constructor.build_tree(alignment)
rag2_tree.rooted = True
print(rag2_tree)

# %%
rag2_tree = Phylo.read(file="data/rag2_tree.xml", format= "phyloxml")

import matplotlib
import matplotlib.pyplot as plt
fig = Phylo.draw(rag2_tree)

# %% [markdown]
# ## Bibliografia
# 1.  Kampen KR, Sulima SO, Vereecke S, De Keersmaecker K. Hallmarks of ribosomopathies. Nucleic Acids Res. 2020 Feb
#     20;48(3):1013-1028. doi: 10.1093/nar/gkz637. PMID: 31350888; PMCID: PMC7026650.
# 2.  Kim HJ, Maiti P, Barrientos A. Mitochondrial ribosomes in cancer. Semin Cancer Biol. 2017 Dec;47:67-81.
#     doi: 10.1016/j.semcancer.2017.04.004. Epub 2017 Apr 23. PMID: 28445780; PMCID: PMC5662495.
# 3.  Kitakawa M, Isono K. The mitochondrial ribosomes. Biochimie. 1991 Jun;73(6):813-25.
#     doi: 10.1016/0300-9084(91)90061-5. PMID: 1764526.
# 4.  Wilson DN, Doudna Cate JH. The structure and function of the eukaryotic ribosome. Cold Spring Harb Perspect Biol. 2012 May 1;4(5):a011536. doi: 10.1101/cshperspect.a011536. PMID: 22550233; PMCID: PMC3331703.
# 6.  Biopython · Biopython. (s. f.). Biopython.Org. Recuperado 19 de agosto de 2022, de https://biopython.org/
# 7.  Chang, J. (s. f.). Biopython Tutorial and Cookbook. Biopython.Org. Recuperado 19 de agosto de 2022, de http://biopython.org/DIST/docs/tutorial/Tutorial.html#sec3
